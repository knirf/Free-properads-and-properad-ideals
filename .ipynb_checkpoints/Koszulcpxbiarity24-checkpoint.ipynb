# %% [markdown]
# # Study of the Koszul complex in biarity $(2, 4)$ and weight $4$
#
# First we just import the modules. See Tutorial.ipynb for more details.

# %%
import time
import pickle
import os
import numpy as np

# %runfile Modules/Part_Tab_Clifton.sage
# %runfile Modules/Clift_Mat.sage
# %runfile Modules/Groebner.sage
# %runfile Modules/Manip_Matrices.sage
# %runfile Modules/Permutations.sage
# %runfile Modules/Remove_Duplicates.sage
# %runfile Modules/Vertex.sage
# %runfile Modules/Labelled_Vertex.sage
# %runfile Modules/Edge.sage
# %runfile Modules/Graph.sage
# %runfile Modules/Graph_Perm.sage
# %runfile Modules/Free_Properad.sage
# %runfile Modules/Ideal_Properad.sage
# %runfile Modules/Coproperad_Dual.sage
# %runfile Modules/First_Definitions.sage
# Out:
# Generating first objects, properads and ideals, could take a few seconds
# If you don't have any file with these properads, it could take some minutes
# You can read readme.txt for more informations.
# Classic properad without permutations : Prop_classic
# Weights generated from file : [0, 1, 2, 3, 4]
# Classic properad with permutations : Prop_classic_perm
# Weights generated from file : [0, 1, 2, 3, 4]
# Classic ideal with Polynomial relations : Ideal_classic_polynomials
# Steps generated from file : [0, 1]
# Orthogonal ideal with polynomial relations : Ideal_orth_polynomials
# Steps generated from file : [0, 1]

# %% [markdown]
# Here we get only the arity $(2, 4)$ and weight $4$ of the ideal stored in a dictionnary which keys are the partition couples of $(2, 3)$. Then we get the Clifton matrices, simplify them and save the result in csv files.
#
# The first row is used in order to compute the arity $(2, 4)$ for the first time, the two next rows are used here to get back the result when it is already computed.
#
# What we print here is, first, the coefficients $k_{\lambda, \mu}$ and the dimensions of $B^a_{\lambda, \mu}$, then we print then number of rows and columns we managed to remove and the possible rank of the new matrix.

# %%
#arity24 = Ideal_classic_polynomials.generate_arity_only_identities((2, 4))
with open("Files/Ideals/Ideal_classic_polynomials_only_identities_arity(2, 4)", 'rb') as file:
    arity24 = pickle.load(file)
dic_matrix24 = create_Cliftons(arity24)
dic_matrix_simple24 = Clifton_matrix_simple(dic_matrix24)
save_matrices_csv(dic_matrix_simple24, "arity24/","")
# Out:
# Couple : ([2], [4])
# Minimal rank : 73, dimensions of remaining matrix : [23, 20]
# Couple : ([2], [3, 1])
# Minimal rank : 219, dimensions of remaining matrix : [69, 60]
# Couple : ([2], [2, 2])
# Minimal rank : 146, dimensions of remaining matrix : [46, 40]
# Couple : ([2], [2, 1, 1])
# Minimal rank : 219, dimensions of remaining matrix : [69, 60]
# Couple : ([2], [1, 1, 1, 1])
# Minimal rank : 73, dimensions of remaining matrix : [23, 20]
# Couple : ([1, 1], [4])
# Minimal rank : 73, dimensions of remaining matrix : [23, 20]
# Couple : ([1, 1], [3, 1])
# Minimal rank : 219, dimensions of remaining matrix : [69, 60]
# Couple : ([1, 1], [2, 2])
# Minimal rank : 146, dimensions of remaining matrix : [46, 40]
# Couple : ([1, 1], [2, 1, 1])
# Minimal rank : 219, dimensions of remaining matrix : [69, 60]
# Couple : ([1, 1], [1, 1, 1, 1])
# Minimal rank : 73, dimensions of remaining matrix : [23, 20]
# Couple : ([2], [4])
# Removed 14 rows and 0 columns
# Rank is in [0, 9]
# Couple : ([2], [3, 1])
# Removed 42 rows and 4 columns
# Rank is in [0, 27]
# Couple : ([2], [2, 2])
# Removed 28 rows and 4 columns
# Rank is in [0, 18]
# Couple : ([2], [2, 1, 1])
# Removed 42 rows and 8 columns
# Rank is in [0, 27]
# Couple : ([2], [1, 1, 1, 1])
# Removed 14 rows and 4 columns
# Rank is in [0, 9]
# Couple : ([1, 1], [4])
# Removed 14 rows and 0 columns
# Rank is in [0, 9]
# Couple : ([1, 1], [3, 1])
# Removed 42 rows and 4 columns
# Rank is in [0, 27]
# Couple : ([1, 1], [2, 2])
# Removed 28 rows and 4 columns
# Rank is in [0, 18]
# Couple : ([1, 1], [2, 1, 1])
# Removed 42 rows and 8 columns
# Rank is in [0, 27]
# Couple : ([1, 1], [1, 1, 1, 1])
# Removed 14 rows and 4 columns
# Rank is in [0, 9]

# %% [markdown]
# We do the same for the orthogonal ideal.

# %%
arity_orth24 = Ideal_orth_polynomials.generate_arity_only_identities((2, 4))
#with open("Files/Ideals/Ideal_orth_polynomials_only_identities_arity(2, 4)", 'rb') as file:
#    arity_orth24 = pickle.load(file)
dic_matrix_orth24 = create_Cliftons(arity_orth24)
dic_matrix_simple_orth24 = Clifton_matrix_simple(dic_matrix_orth24)
save_matrices_csv(dic_matrix_simple_orth24, "orth_arity24/", "")
# Out:
# Generated all graphs
# backup found, building from 6300
# 6301/12576 : took 0 minutes and 3 seconds.
# 6302/12576 : took 0 minutes and 9 seconds.
# 6303/12576 : took 0 minutes and 12 seconds.
# 6304/12576 : took 0 minutes and 16 seconds.
# 6305/12576 : took 0 minutes and 18 seconds.
# 6306/12576 : took 0 minutes and 22 seconds.
# 6307/12576 : took 0 minutes and 25 seconds.
# 6308/12576 : took 0 minutes and 28 seconds.
# 6309/12576 : took 0 minutes and 29 seconds.
# 6310/12576 : took 0 minutes and 29 seconds.
# 6311/12576 : took 0 minutes and 30 seconds.
# 6312/12576 : took 0 minutes and 31 seconds.
# 6313/12576 : took 0 minutes and 31 seconds.
# 6314/12576 : took 0 minutes and 32 seconds.
# 6315/12576 : took 0 minutes and 35 seconds.
# 6316/12576 : took 0 minutes and 43 seconds.
# 6317/12576 : took 0 minutes and 46 seconds.
# 6318/12576 : took 0 minutes and 50 seconds.
# 6319/12576 : took 0 minutes and 53 seconds.
# 6320/12576 : took 0 minutes and 56 seconds.
# 6321/12576 : took 1 minutes and 0 seconds.
# 6322/12576 : took 1 minutes and 3 seconds.
# 6323/12576 : took 1 minutes and 4 seconds.
# 6324/12576 : took 1 minutes and 5 seconds.
# 6325/12576 : took 1 minutes and 5 seconds.
# 6326/12576 : took 1 minutes and 6 seconds.
# 6327/12576 : took 1 minutes and 6 seconds.
# 6328/12576 : took 1 minutes and 7 seconds.
# 6329/12576 : took 1 minutes and 10 seconds.
# 6330/12576 : took 1 minutes and 13 seconds.
# 6331/12576 : took 1 minutes and 17 seconds.
# 6332/12576 : took 1 minutes and 20 seconds.
# 6333/12576 : took 1 minutes and 23 seconds.
# Minimal rank : 276, dimensions of remaining matrix : [273, 3]
# Couple : ([1, 1], [2, 2])
# Minimal rank : 184, dimensions of remaining matrix : [182, 2]
# Couple : ([1, 1], [2, 1, 1])
# Minimal rank : 276, dimensions of remaining matrix : [273, 3]
# Couple : ([1, 1], [1, 1, 1, 1])
# Minimal rank : 92, dimensions of remaining matrix : [91, 1]
# Couple : ([2], [4])
# Removed 71 rows and 0 columns
# Rank is in [0, 1]
# Couple : ([2], [3, 1])
# Removed 192 rows and 0 columns
# Rank is in [0, 3]
# Couple : ([2], [2, 2])
# Removed 117 rows and 0 columns
# Rank is in [0, 2]
# Couple : ([2], [2, 1, 1])
# Removed 171 rows and 0 columns
# Rank is in [0, 3]
# Couple : ([2], [1, 1, 1, 1])
# Removed 63 rows and 0 columns
# Rank is in [0, 1]
# Couple : ([1, 1], [4])
# Removed 71 rows and 0 columns
# Rank is in [0, 1]
# Couple : ([1, 1], [3, 1])
# Removed 192 rows and 0 columns
# Rank is in [0, 3]
# Couple : ([1, 1], [2, 2])
# Removed 117 rows and 0 columns
# Rank is in [0, 2]
# Couple : ([1, 1], [2, 1, 1])
# Removed 171 rows and 0 columns
# Rank is in [0, 3]
# Couple : ([1, 1], [1, 1, 1, 1])
# Removed 63 rows and 0 columns
# Rank is in [0, 1]

# %% [markdown]
# ## Orthogonal ideal
#
# With Groebner basis, we can compute the rank $rk(B_{\lambda, \mu}^{a, \perp})$ in terms of $a$.

# %%
res = {}
for couple in dic_matrix_simple_orth24:
    print("Couple : " + str(couple))
    M = dic_matrix_simple_orth24[couple][1]
    res[couple] = groebner_bas(M)
    print("Groebner basis : " + str(res[couple][2]))
# Out:
# Couple : ([2], [4])
# Matrix size : (20, 1)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a3^2 - a3, a4^2 - a4]]
# Couple : ([2], [3, 1])
# Matrix size : (81, 3)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 2
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 3
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4], [a1^4 + (-2.00000000000000)*a1^3 + a1^2, a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2, a2^4 + (-2.00000000000000)*a2^3 + a2^2, a1*a2^2*a3 - a1*a2*a3, a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3, a1*a3^3 - a1*a3^2, a3^4 + (-2.00000000000000)*a3^3 + a3^2, a1^2*a2*a4 - a1*a2*a4, a1*a2*a3*a4, a2*a3^2*a4 - a2*a3*a4, a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4, a1*a3*a4^2 - a1*a3*a4, a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4, a2*a4^3 - a2*a4^2, a4^4 + (-2.00000000000000)*a4^3 + a4^2, a1^2*a3 + a1*a3^2 - a1*a3, a2^2*a4 + a2*a4^2 - a2*a4], Polynomial Sequence with 34 Polynomials in 4 Variables]
# Couple : ([2], [2, 2])
# Matrix size : (65, 2)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 2
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4], [a1^4 + (-2.00000000000000)*a1^3 + a1^2, a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2, a2^4 + (-2.00000000000000)*a2^3 + a2^2, a1*a2^2*a3 - a1*a2*a3, a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3, a1*a3^3 - a1*a3^2, a3^4 + (-2.00000000000000)*a3^3 + a3^2, a1^2*a2*a4 - a1*a2*a4, a1*a2*a3*a4, a2*a3^2*a4 - a2*a3*a4, a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4, a1*a3*a4^2 - a1*a3*a4, a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4, a2*a4^3 - a2*a4^2, a4^4 + (-2.00000000000000)*a4^3 + a4^2, a1^2*a3 + a1*a3^2 - a1*a3, a2^2*a4 + a2*a4^2 - a2*a4]]
# Couple : ([2], [2, 1, 1])
# Matrix size : (102, 3)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 2
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 3
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4], [a1^4 + (-2.00000000000000)*a1^3 + a1^2, a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2, a2^4 + (-2.00000000000000)*a2^3 + a2^2, a1*a2^2*a3 - a1*a2*a3, a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3, a1*a3^3 - a1*a3^2, a3^4 + (-2.00000000000000)*a3^3 + a3^2, a1^2*a2*a4 - a1*a2*a4, a1*a2*a3*a4, a2*a3^2*a4 - a2*a3*a4, a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4, a1*a3*a4^2 - a1*a3*a4, a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4, a2*a4^3 - a2*a4^2, a4^4 + (-2.00000000000000)*a4^3 + a4^2, a1^2*a3 + a1*a3^2 - a1*a3, a2^2*a4 + a2*a4^2 - a2*a4], Polynomial Sequence with 36 Polynomials in 4 Variables]
# Couple : ([2], [1, 1, 1, 1])
# Matrix size : (28, 1)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4]]
# Couple : ([1, 1], [4])
# Matrix size : (20, 1)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a3^2 - a3, a4^2 - a4]]
# Couple : ([1, 1], [3, 1])
# Matrix size : (81, 3)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 2
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 3
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4], [a1^4 + (-2.00000000000000)*a1^3 + a1^2, a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2, a2^4 + (-2.00000000000000)*a2^3 + a2^2, a1*a2^2*a3 - a1*a2*a3, a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3, a1*a3^3 - a1*a3^2, a3^4 + (-2.00000000000000)*a3^3 + a3^2, a1^2*a2*a4 - a1*a2*a4, a1*a2*a3*a4, a2*a3^2*a4 - a2*a3*a4, a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4, a1*a3*a4^2 - a1*a3*a4, a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4, a2*a4^3 - a2*a4^2, a4^4 + (-2.00000000000000)*a4^3 + a4^2, a1^2*a3 + a1*a3^2 - a1*a3, a2^2*a4 + a2*a4^2 - a2*a4], Polynomial Sequence with 34 Polynomials in 4 Variables]
# Couple : ([1, 1], [2, 2])
# Matrix size : (65, 2)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 2
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4], [a1^4 + (-2.00000000000000)*a1^3 + a1^2, a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2, a2^4 + (-2.00000000000000)*a2^3 + a2^2, a1*a2^2*a3 - a1*a2*a3, a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3, a1*a3^3 - a1*a3^2, a3^4 + (-2.00000000000000)*a3^3 + a3^2, a1^2*a2*a4 - a1*a2*a4, a1*a2*a3*a4, a2*a3^2*a4 - a2*a3*a4, a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4, a1*a3*a4^2 - a1*a3*a4, a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4, a2*a4^3 - a2*a4^2, a4^4 + (-2.00000000000000)*a4^3 + a4^2, a1^2*a3 + a1*a3^2 - a1*a3, a2^2*a4 + a2*a4^2 - a2*a4]]
# Couple : ([1, 1], [2, 1, 1])
# Matrix size : (102, 3)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 2
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Minors of size 3
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4], [a1^4 + (-2.00000000000000)*a1^3 + a1^2, a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2, a2^4 + (-2.00000000000000)*a2^3 + a2^2, a1*a2^2*a3 - a1*a2*a3, a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3, a1*a3^3 - a1*a3^2, a3^4 + (-2.00000000000000)*a3^3 + a3^2, a1^2*a2*a4 - a1*a2*a4, a1*a2*a3*a4, a2*a3^2*a4 - a2*a3*a4, a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4, a1*a3*a4^2 - a1*a3*a4, a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4, a2*a4^3 - a2*a4^2, a4^4 + (-2.00000000000000)*a4^3 + a4^2, a1^2*a3 + a1*a3^2 - a1*a3, a2^2*a4 + a2*a4^2 - a2*a4], Polynomial Sequence with 36 Polynomials in 4 Variables]
# Couple : ([1, 1], [1, 1, 1, 1])
# Matrix size : (28, 1)
# Minors of size 1
# All minors calculated
# Ideal defined
# Groebner Basis calculated
# Groebner basis : [[a1^2 - a1, a2^2 - a2, a1*a3, a3^2 - a3, a2*a4, a4^2 - a4]]

# %% [markdown]
# Here we print, for every couple of partitions, every polynomials in the Gröbner basis of the determinental ideal $DI_i$, and their projections into the quotient ring $\mathbb{C}[a2, a3, a4, a5]/(ai^2 - ai)$. This gives us the rank of the matrices in the subsets $NC_1$ and $NC_{x, 0}$.

# %%
Sa = Ra.quotient([a1^2 - a1, a2^2 - a2, a3^2 - a3, a4^2 - a4])
for couple in res:
    print(couple)
    Gbasis = res[couple][2]
    n = len(Gbasis)
    print("n = " + str(n))
    for i in range(n):
        print("i = " + str(i+1))
        for p in Gbasis[i]:
            print(str(p) + " and " + str(Sa(p)))
# Out:
# ([2], [4])
# n = 1
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a3^2 - a3 and 0
# a4^2 - a4 and 0
# ([2], [3, 1])
# n = 3
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# i = 2
# a1^4 + (-2.00000000000000)*a1^3 + a1^2 and 0
# a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2 and 0
# a2^4 + (-2.00000000000000)*a2^3 + a2^2 and 0
# a1*a2^2*a3 - a1*a2*a3 and 0
# a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3 and 0
# a1*a3^3 - a1*a3^2 and 0
# a3^4 + (-2.00000000000000)*a3^3 + a3^2 and 0
# a1^2*a2*a4 - a1*a2*a4 and 0
# a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2*a3^2*a4 - a2*a3*a4 and 0
# a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4 and 0
# a1*a3*a4^2 - a1*a3*a4 and 0
# a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4 and 0
# a2*a4^3 - a2*a4^2 and 0
# a4^4 + (-2.00000000000000)*a4^3 + a4^2 and 0
# a1^2*a3 + a1*a3^2 - a1*a3 and a1bar*a3bar
# a2^2*a4 + a2*a4^2 - a2*a4 and a2bar*a4bar
# i = 3
# a1^6 + (-3.00000000000000)*a1^5 + 3.00000000000000*a1^4 - a1^3 and 0
# a1^4*a2^2 - a1^4*a2 + (-2.00000000000000)*a1^3*a2^2 + 2.00000000000000*a1^3*a2 + a1^2*a2^2 - a1^2*a2 and 0
# a1^2*a2^4 + (-2.00000000000000)*a1^2*a2^3 - a1*a2^4 + a1^2*a2^2 + 2.00000000000000*a1*a2^3 - a1*a2^2 and 0
# a2^6 + (-3.00000000000000)*a2^5 + 3.00000000000000*a2^4 - a2^3 and 0
# a1*a2^4*a3 + (-2.00000000000000)*a1*a2^3*a3 + a1*a2^2*a3 and 0
# a2^4*a3^2 - a2^4*a3 + (-2.00000000000000)*a2^3*a3^2 + 2.00000000000000*a2^3*a3 + a2^2*a3^2 - a2^2*a3 and 0
# a1*a2^2*a3^3 - a1*a2^2*a3^2 - a1*a2*a3^3 + a1*a2*a3^2 and 0
# a2^2*a3^4 + (-2.00000000000000)*a2^2*a3^3 - a2*a3^4 + a2^2*a3^2 + 2.00000000000000*a2*a3^3 - a2*a3^2 and 0
# a1*a3^5 + (-2.00000000000000)*a1*a3^4 + a1*a3^3 and 0
# a3^6 + (-3.00000000000000)*a3^5 + 3.00000000000000*a3^4 - a3^3 and 0
# a1^4*a2*a4 + (-2.00000000000000)*a1^3*a2*a4 + a1^2*a2*a4 and 0
# a1*a2*a3^3*a4 - a1*a2*a3^2*a4 and 0
# a2*a3^4*a4 + (-2.00000000000000)*a2*a3^3*a4 + a2*a3^2*a4 and 0
# a1^4*a4^2 - a1^4*a4 + (-2.00000000000000)*a1^3*a4^2 + 2.00000000000000*a1^3*a4 + a1^2*a4^2 - a1^2*a4 and 0
# a1*a3^3*a4^2 - a1*a3^3*a4 - a1*a3^2*a4^2 + a1*a3^2*a4 and 0
# a3^4*a4^2 - a3^4*a4 + (-2.00000000000000)*a3^3*a4^2 + 2.00000000000000*a3^3*a4 + a3^2*a4^2 - a3^2*a4 and 0
# a1^2*a2*a4^3 - a1^2*a2*a4^2 - a1*a2*a4^3 + a1*a2*a4^2 and 0
# a1*a2*a3*a4^3 - a1*a2*a3*a4^2 and 0
# a2*a3^2*a4^3 - a2*a3^2*a4^2 - a2*a3*a4^3 + a2*a3*a4^2 and 0
# a1^2*a4^4 + (-2.00000000000000)*a1^2*a4^3 - a1*a4^4 + a1^2*a4^2 + 2.00000000000000*a1*a4^3 - a1*a4^2 and 0
# a1*a3*a4^4 + (-2.00000000000000)*a1*a3*a4^3 + a1*a3*a4^2 and 0
# a3^2*a4^4 + (-2.00000000000000)*a3^2*a4^3 - a3*a4^4 + a3^2*a4^2 + 2.00000000000000*a3*a4^3 - a3*a4^2 and 0
# a2*a4^5 + (-2.00000000000000)*a2*a4^4 + a2*a4^3 and 0
# a4^6 + (-3.00000000000000)*a4^5 + 3.00000000000000*a4^4 - a4^3 and 0
# a1^4*a3 + a1^3*a3^2 + (-2.00000000000000)*a1^3*a3 - a1^2*a3^2 + a1^2*a3 and 0
# a1^2*a2^2*a3 + a1*a2^2*a3^2 - a1^2*a2*a3 - a1*a2^2*a3 - a1*a2*a3^2 + a1*a2*a3 and 0
# a1^2*a3^3 + a1*a3^4 - a1^2*a3^2 + (-2.00000000000000)*a1*a3^3 + a1*a3^2 and 0
# a1^2*a2^2*a4 + a1^2*a2*a4^2 - a1^2*a2*a4 - a1*a2^2*a4 - a1*a2*a4^2 + a1*a2*a4 and 0
# a2^4*a4 + a2^3*a4^2 + (-2.00000000000000)*a2^3*a4 - a2^2*a4^2 + a2^2*a4 and 0
# a1^2*a2*a3*a4 + a1*a2*a3^2*a4 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a1*a2^2*a3*a4 + a1*a2*a3*a4^2 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2^2*a3^2*a4 + a2*a3^2*a4^2 - a2^2*a3*a4 - a2*a3^2*a4 - a2*a3*a4^2 + a2*a3*a4 and 0
# a1^2*a3*a4^2 + a1*a3^2*a4^2 - a1^2*a3*a4 - a1*a3^2*a4 - a1*a3*a4^2 + a1*a3*a4 and 0
# a2^2*a4^3 + a2*a4^4 - a2^2*a4^2 + (-2.00000000000000)*a2*a4^3 + a2*a4^2 and 0
# ([2], [2, 2])
# n = 2
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# i = 2
# a1^4 + (-2.00000000000000)*a1^3 + a1^2 and 0
# a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2 and 0
# a2^4 + (-2.00000000000000)*a2^3 + a2^2 and 0
# a1*a2^2*a3 - a1*a2*a3 and 0
# a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3 and 0
# a1*a3^3 - a1*a3^2 and 0
# a3^4 + (-2.00000000000000)*a3^3 + a3^2 and 0
# a1^2*a2*a4 - a1*a2*a4 and 0
# a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2*a3^2*a4 - a2*a3*a4 and 0
# a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4 and 0
# a1*a3*a4^2 - a1*a3*a4 and 0
# a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4 and 0
# a2*a4^3 - a2*a4^2 and 0
# a4^4 + (-2.00000000000000)*a4^3 + a4^2 and 0
# a1^2*a3 + a1*a3^2 - a1*a3 and a1bar*a3bar
# a2^2*a4 + a2*a4^2 - a2*a4 and a2bar*a4bar
# ([2], [2, 1, 1])
# n = 3
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# i = 2
# a1^4 + (-2.00000000000000)*a1^3 + a1^2 and 0
# a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2 and 0
# a2^4 + (-2.00000000000000)*a2^3 + a2^2 and 0
# a1*a2^2*a3 - a1*a2*a3 and 0
# a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3 and 0
# a1*a3^3 - a1*a3^2 and 0
# a3^4 + (-2.00000000000000)*a3^3 + a3^2 and 0
# a1^2*a2*a4 - a1*a2*a4 and 0
# a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2*a3^2*a4 - a2*a3*a4 and 0
# a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4 and 0
# a1*a3*a4^2 - a1*a3*a4 and 0
# a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4 and 0
# a2*a4^3 - a2*a4^2 and 0
# a4^4 + (-2.00000000000000)*a4^3 + a4^2 and 0
# a1^2*a3 + a1*a3^2 - a1*a3 and a1bar*a3bar
# a2^2*a4 + a2*a4^2 - a2*a4 and a2bar*a4bar
# i = 3
# a1^6 + (-3.00000000000000)*a1^5 + 3.00000000000000*a1^4 - a1^3 and 0
# a1^4*a2^2 - a1^4*a2 + (-2.00000000000000)*a1^3*a2^2 + 2.00000000000000*a1^3*a2 + a1^2*a2^2 - a1^2*a2 and 0
# a1^2*a2^4 + (-2.00000000000000)*a1^2*a2^3 - a1*a2^4 + a1^2*a2^2 + 2.00000000000000*a1*a2^3 - a1*a2^2 and 0
# a2^6 + (-3.00000000000000)*a2^5 + 3.00000000000000*a2^4 - a2^3 and 0
# a1*a2^4*a3 + (-2.00000000000000)*a1*a2^3*a3 + a1*a2^2*a3 and 0
# a2^4*a3^2 - a2^4*a3 + (-2.00000000000000)*a2^3*a3^2 + 2.00000000000000*a2^3*a3 + a2^2*a3^2 - a2^2*a3 and 0
# a1*a2^2*a3^3 - a1*a2^2*a3^2 - a1*a2*a3^3 + a1*a2*a3^2 and 0
# a2^2*a3^4 + (-2.00000000000000)*a2^2*a3^3 - a2*a3^4 + a2^2*a3^2 + 2.00000000000000*a2*a3^3 - a2*a3^2 and 0
# a1*a3^5 + (-2.00000000000000)*a1*a3^4 + a1*a3^3 and 0
# a3^6 + (-3.00000000000000)*a3^5 + 3.00000000000000*a3^4 - a3^3 and 0
# a1^4*a2*a4 + (-2.00000000000000)*a1^3*a2*a4 + a1^2*a2*a4 and 0
# a1*a2*a3^3*a4 - a1*a2*a3^2*a4 and 0
# a2*a3^4*a4 + (-2.00000000000000)*a2*a3^3*a4 + a2*a3^2*a4 and 0
# a1^4*a4^2 - a1^4*a4 + (-2.00000000000000)*a1^3*a4^2 + 2.00000000000000*a1^3*a4 + a1^2*a4^2 - a1^2*a4 and 0
# a1*a3^3*a4^2 - a1*a3^3*a4 - a1*a3^2*a4^2 + a1*a3^2*a4 and 0
# a3^4*a4^2 - a3^4*a4 + (-2.00000000000000)*a3^3*a4^2 + 2.00000000000000*a3^3*a4 + a3^2*a4^2 - a3^2*a4 and 0
# a1^2*a2*a4^3 - a1^2*a2*a4^2 - a1*a2*a4^3 + a1*a2*a4^2 and 0
# a1*a2*a3*a4^3 - a1*a2*a3*a4^2 and 0
# a2*a3^2*a4^3 - a2*a3^2*a4^2 - a2*a3*a4^3 + a2*a3*a4^2 and 0
# a1^2*a4^4 + (-2.00000000000000)*a1^2*a4^3 - a1*a4^4 + a1^2*a4^2 + 2.00000000000000*a1*a4^3 - a1*a4^2 and 0
# a1*a3*a4^4 + (-2.00000000000000)*a1*a3*a4^3 + a1*a3*a4^2 and 0
# a3^2*a4^4 + (-2.00000000000000)*a3^2*a4^3 - a3*a4^4 + a3^2*a4^2 + 2.00000000000000*a3*a4^3 - a3*a4^2 and 0
# a2*a4^5 + (-2.00000000000000)*a2*a4^4 + a2*a4^3 and 0
# a4^6 + (-3.00000000000000)*a4^5 + 3.00000000000000*a4^4 - a4^3 and 0
# a1^4*a3 + a1*a3^4 + (-2.00000000000000)*a1^3*a3 - a1^2*a3^2 + (-2.00000000000000)*a1*a3^3 + a1^2*a3 + a1*a3^2 and -a1bar*a3bar
# a1^2*a2^2*a3 + a1*a2^2*a3^2 - a1^2*a2*a3 - a1*a2^2*a3 - a1*a2*a3^2 + a1*a2*a3 and 0
# a1^3*a3^2 - a1*a3^4 + 2.00000000000000*a1*a3^3 - a1*a3^2 and a1bar*a3bar
# a1^2*a3^3 + a1*a3^4 - a1^2*a3^2 + (-2.00000000000000)*a1*a3^3 + a1*a3^2 and 0
# a1^2*a2^2*a4 + a1^2*a2*a4^2 - a1^2*a2*a4 - a1*a2^2*a4 - a1*a2*a4^2 + a1*a2*a4 and 0
# a2^4*a4 + a2*a4^4 + (-2.00000000000000)*a2^3*a4 - a2^2*a4^2 + (-2.00000000000000)*a2*a4^3 + a2^2*a4 + a2*a4^2 and -a2bar*a4bar
# a1^2*a2*a3*a4 + a1*a2*a3^2*a4 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a1*a2^2*a3*a4 + a1*a2*a3*a4^2 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2^2*a3^2*a4 + a2*a3^2*a4^2 - a2^2*a3*a4 - a2*a3^2*a4 - a2*a3*a4^2 + a2*a3*a4 and 0
# a2^3*a4^2 - a2*a4^4 + 2.00000000000000*a2*a4^3 - a2*a4^2 and a2bar*a4bar
# a1^2*a3*a4^2 + a1*a3^2*a4^2 - a1^2*a3*a4 - a1*a3^2*a4 - a1*a3*a4^2 + a1*a3*a4 and 0
# a2^2*a4^3 + a2*a4^4 - a2^2*a4^2 + (-2.00000000000000)*a2*a4^3 + a2*a4^2 and 0
# ([2], [1, 1, 1, 1])
# n = 1
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# ([1, 1], [4])
# n = 1
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a3^2 - a3 and 0
# a4^2 - a4 and 0
# ([1, 1], [3, 1])
# n = 3
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# i = 2
# a1^4 + (-2.00000000000000)*a1^3 + a1^2 and 0
# a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2 and 0
# a2^4 + (-2.00000000000000)*a2^3 + a2^2 and 0
# a1*a2^2*a3 - a1*a2*a3 and 0
# a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3 and 0
# a1*a3^3 - a1*a3^2 and 0
# a3^4 + (-2.00000000000000)*a3^3 + a3^2 and 0
# a1^2*a2*a4 - a1*a2*a4 and 0
# a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2*a3^2*a4 - a2*a3*a4 and 0
# a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4 and 0
# a1*a3*a4^2 - a1*a3*a4 and 0
# a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4 and 0
# a2*a4^3 - a2*a4^2 and 0
# a4^4 + (-2.00000000000000)*a4^3 + a4^2 and 0
# a1^2*a3 + a1*a3^2 - a1*a3 and a1bar*a3bar
# a2^2*a4 + a2*a4^2 - a2*a4 and a2bar*a4bar
# i = 3
# a1^6 + (-3.00000000000000)*a1^5 + 3.00000000000000*a1^4 - a1^3 and 0
# a1^4*a2^2 - a1^4*a2 + (-2.00000000000000)*a1^3*a2^2 + 2.00000000000000*a1^3*a2 + a1^2*a2^2 - a1^2*a2 and 0
# a1^2*a2^4 + (-2.00000000000000)*a1^2*a2^3 - a1*a2^4 + a1^2*a2^2 + 2.00000000000000*a1*a2^3 - a1*a2^2 and 0
# a2^6 + (-3.00000000000000)*a2^5 + 3.00000000000000*a2^4 - a2^3 and 0
# a1*a2^4*a3 + (-2.00000000000000)*a1*a2^3*a3 + a1*a2^2*a3 and 0
# a2^4*a3^2 - a2^4*a3 + (-2.00000000000000)*a2^3*a3^2 + 2.00000000000000*a2^3*a3 + a2^2*a3^2 - a2^2*a3 and 0
# a1*a2^2*a3^3 - a1*a2^2*a3^2 - a1*a2*a3^3 + a1*a2*a3^2 and 0
# a2^2*a3^4 + (-2.00000000000000)*a2^2*a3^3 - a2*a3^4 + a2^2*a3^2 + 2.00000000000000*a2*a3^3 - a2*a3^2 and 0
# a1*a3^5 + (-2.00000000000000)*a1*a3^4 + a1*a3^3 and 0
# a3^6 + (-3.00000000000000)*a3^5 + 3.00000000000000*a3^4 - a3^3 and 0
# a1^4*a2*a4 + (-2.00000000000000)*a1^3*a2*a4 + a1^2*a2*a4 and 0
# a1*a2*a3^3*a4 - a1*a2*a3^2*a4 and 0
# a2*a3^4*a4 + (-2.00000000000000)*a2*a3^3*a4 + a2*a3^2*a4 and 0
# a1^4*a4^2 - a1^4*a4 + (-2.00000000000000)*a1^3*a4^2 + 2.00000000000000*a1^3*a4 + a1^2*a4^2 - a1^2*a4 and 0
# a1*a3^3*a4^2 - a1*a3^3*a4 - a1*a3^2*a4^2 + a1*a3^2*a4 and 0
# a3^4*a4^2 - a3^4*a4 + (-2.00000000000000)*a3^3*a4^2 + 2.00000000000000*a3^3*a4 + a3^2*a4^2 - a3^2*a4 and 0
# a1^2*a2*a4^3 - a1^2*a2*a4^2 - a1*a2*a4^3 + a1*a2*a4^2 and 0
# a1*a2*a3*a4^3 - a1*a2*a3*a4^2 and 0
# a2*a3^2*a4^3 - a2*a3^2*a4^2 - a2*a3*a4^3 + a2*a3*a4^2 and 0
# a1^2*a4^4 + (-2.00000000000000)*a1^2*a4^3 - a1*a4^4 + a1^2*a4^2 + 2.00000000000000*a1*a4^3 - a1*a4^2 and 0
# a1*a3*a4^4 + (-2.00000000000000)*a1*a3*a4^3 + a1*a3*a4^2 and 0
# a3^2*a4^4 + (-2.00000000000000)*a3^2*a4^3 - a3*a4^4 + a3^2*a4^2 + 2.00000000000000*a3*a4^3 - a3*a4^2 and 0
# a2*a4^5 + (-2.00000000000000)*a2*a4^4 + a2*a4^3 and 0
# a4^6 + (-3.00000000000000)*a4^5 + 3.00000000000000*a4^4 - a4^3 and 0
# a1^4*a3 + a1^3*a3^2 + (-2.00000000000000)*a1^3*a3 - a1^2*a3^2 + a1^2*a3 and 0
# a1^2*a2^2*a3 + a1*a2^2*a3^2 - a1^2*a2*a3 - a1*a2^2*a3 - a1*a2*a3^2 + a1*a2*a3 and 0
# a1^2*a3^3 + a1*a3^4 - a1^2*a3^2 + (-2.00000000000000)*a1*a3^3 + a1*a3^2 and 0
# a1^2*a2^2*a4 + a1^2*a2*a4^2 - a1^2*a2*a4 - a1*a2^2*a4 - a1*a2*a4^2 + a1*a2*a4 and 0
# a2^4*a4 + a2^3*a4^2 + (-2.00000000000000)*a2^3*a4 - a2^2*a4^2 + a2^2*a4 and 0
# a1^2*a2*a3*a4 + a1*a2*a3^2*a4 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a1*a2^2*a3*a4 + a1*a2*a3*a4^2 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2^2*a3^2*a4 + a2*a3^2*a4^2 - a2^2*a3*a4 - a2*a3^2*a4 - a2*a3*a4^2 + a2*a3*a4 and 0
# a1^2*a3*a4^2 + a1*a3^2*a4^2 - a1^2*a3*a4 - a1*a3^2*a4 - a1*a3*a4^2 + a1*a3*a4 and 0
# a2^2*a4^3 + a2*a4^4 - a2^2*a4^2 + (-2.00000000000000)*a2*a4^3 + a2*a4^2 and 0
# ([1, 1], [2, 2])
# n = 2
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# i = 2
# a1^4 + (-2.00000000000000)*a1^3 + a1^2 and 0
# a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2 and 0
# a2^4 + (-2.00000000000000)*a2^3 + a2^2 and 0
# a1*a2^2*a3 - a1*a2*a3 and 0
# a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3 and 0
# a1*a3^3 - a1*a3^2 and 0
# a3^4 + (-2.00000000000000)*a3^3 + a3^2 and 0
# a1^2*a2*a4 - a1*a2*a4 and 0
# a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2*a3^2*a4 - a2*a3*a4 and 0
# a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4 and 0
# a1*a3*a4^2 - a1*a3*a4 and 0
# a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4 and 0
# a2*a4^3 - a2*a4^2 and 0
# a4^4 + (-2.00000000000000)*a4^3 + a4^2 and 0
# a1^2*a3 + a1*a3^2 - a1*a3 and a1bar*a3bar
# a2^2*a4 + a2*a4^2 - a2*a4 and a2bar*a4bar
# ([1, 1], [2, 1, 1])
# n = 3
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0
# i = 2
# a1^4 + (-2.00000000000000)*a1^3 + a1^2 and 0
# a1^2*a2^2 - a1^2*a2 - a1*a2^2 + a1*a2 and 0
# a2^4 + (-2.00000000000000)*a2^3 + a2^2 and 0
# a1*a2^2*a3 - a1*a2*a3 and 0
# a2^2*a3^2 - a2^2*a3 - a2*a3^2 + a2*a3 and 0
# a1*a3^3 - a1*a3^2 and 0
# a3^4 + (-2.00000000000000)*a3^3 + a3^2 and 0
# a1^2*a2*a4 - a1*a2*a4 and 0
# a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2*a3^2*a4 - a2*a3*a4 and 0
# a1^2*a4^2 - a1^2*a4 - a1*a4^2 + a1*a4 and 0
# a1*a3*a4^2 - a1*a3*a4 and 0
# a3^2*a4^2 - a3^2*a4 - a3*a4^2 + a3*a4 and 0
# a2*a4^3 - a2*a4^2 and 0
# a4^4 + (-2.00000000000000)*a4^3 + a4^2 and 0
# a1^2*a3 + a1*a3^2 - a1*a3 and a1bar*a3bar
# a2^2*a4 + a2*a4^2 - a2*a4 and a2bar*a4bar
# i = 3
# a1^6 + (-3.00000000000000)*a1^5 + 3.00000000000000*a1^4 - a1^3 and 0
# a1^4*a2^2 - a1^4*a2 + (-2.00000000000000)*a1^3*a2^2 + 2.00000000000000*a1^3*a2 + a1^2*a2^2 - a1^2*a2 and 0
# a1^2*a2^4 + (-2.00000000000000)*a1^2*a2^3 - a1*a2^4 + a1^2*a2^2 + 2.00000000000000*a1*a2^3 - a1*a2^2 and 0
# a2^6 + (-3.00000000000000)*a2^5 + 3.00000000000000*a2^4 - a2^3 and 0
# a1*a2^4*a3 + (-2.00000000000000)*a1*a2^3*a3 + a1*a2^2*a3 and 0
# a2^4*a3^2 - a2^4*a3 + (-2.00000000000000)*a2^3*a3^2 + 2.00000000000000*a2^3*a3 + a2^2*a3^2 - a2^2*a3 and 0
# a1*a2^2*a3^3 - a1*a2^2*a3^2 - a1*a2*a3^3 + a1*a2*a3^2 and 0
# a2^2*a3^4 + (-2.00000000000000)*a2^2*a3^3 - a2*a3^4 + a2^2*a3^2 + 2.00000000000000*a2*a3^3 - a2*a3^2 and 0
# a1*a3^5 + (-2.00000000000000)*a1*a3^4 + a1*a3^3 and 0
# a3^6 + (-3.00000000000000)*a3^5 + 3.00000000000000*a3^4 - a3^3 and 0
# a1^4*a2*a4 + (-2.00000000000000)*a1^3*a2*a4 + a1^2*a2*a4 and 0
# a1*a2*a3^3*a4 - a1*a2*a3^2*a4 and 0
# a2*a3^4*a4 + (-2.00000000000000)*a2*a3^3*a4 + a2*a3^2*a4 and 0
# a1^4*a4^2 - a1^4*a4 + (-2.00000000000000)*a1^3*a4^2 + 2.00000000000000*a1^3*a4 + a1^2*a4^2 - a1^2*a4 and 0
# a1*a3^3*a4^2 - a1*a3^3*a4 - a1*a3^2*a4^2 + a1*a3^2*a4 and 0
# a3^4*a4^2 - a3^4*a4 + (-2.00000000000000)*a3^3*a4^2 + 2.00000000000000*a3^3*a4 + a3^2*a4^2 - a3^2*a4 and 0
# a1^2*a2*a4^3 - a1^2*a2*a4^2 - a1*a2*a4^3 + a1*a2*a4^2 and 0
# a1*a2*a3*a4^3 - a1*a2*a3*a4^2 and 0
# a2*a3^2*a4^3 - a2*a3^2*a4^2 - a2*a3*a4^3 + a2*a3*a4^2 and 0
# a1^2*a4^4 + (-2.00000000000000)*a1^2*a4^3 - a1*a4^4 + a1^2*a4^2 + 2.00000000000000*a1*a4^3 - a1*a4^2 and 0
# a1*a3*a4^4 + (-2.00000000000000)*a1*a3*a4^3 + a1*a3*a4^2 and 0
# a3^2*a4^4 + (-2.00000000000000)*a3^2*a4^3 - a3*a4^4 + a3^2*a4^2 + 2.00000000000000*a3*a4^3 - a3*a4^2 and 0
# a2*a4^5 + (-2.00000000000000)*a2*a4^4 + a2*a4^3 and 0
# a4^6 + (-3.00000000000000)*a4^5 + 3.00000000000000*a4^4 - a4^3 and 0
# a1^4*a3 + a1*a3^4 + (-2.00000000000000)*a1^3*a3 - a1^2*a3^2 + (-2.00000000000000)*a1*a3^3 + a1^2*a3 + a1*a3^2 and -a1bar*a3bar
# a1^2*a2^2*a3 + a1*a2^2*a3^2 - a1^2*a2*a3 - a1*a2^2*a3 - a1*a2*a3^2 + a1*a2*a3 and 0
# a1^3*a3^2 - a1*a3^4 + 2.00000000000000*a1*a3^3 - a1*a3^2 and a1bar*a3bar
# a1^2*a3^3 + a1*a3^4 - a1^2*a3^2 + (-2.00000000000000)*a1*a3^3 + a1*a3^2 and 0
# a1^2*a2^2*a4 + a1^2*a2*a4^2 - a1^2*a2*a4 - a1*a2^2*a4 - a1*a2*a4^2 + a1*a2*a4 and 0
# a2^4*a4 + a2*a4^4 + (-2.00000000000000)*a2^3*a4 - a2^2*a4^2 + (-2.00000000000000)*a2*a4^3 + a2^2*a4 + a2*a4^2 and -a2bar*a4bar
# a1^2*a2*a3*a4 + a1*a2*a3^2*a4 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a1*a2^2*a3*a4 + a1*a2*a3*a4^2 - a1*a2*a3*a4 and a1bar*a2bar*a3bar*a4bar
# a2^2*a3^2*a4 + a2*a3^2*a4^2 - a2^2*a3*a4 - a2*a3^2*a4 - a2*a3*a4^2 + a2*a3*a4 and 0
# a2^3*a4^2 - a2*a4^4 + 2.00000000000000*a2*a4^3 - a2*a4^2 and a2bar*a4bar
# a1^2*a3*a4^2 + a1*a3^2*a4^2 - a1^2*a3*a4 - a1*a3^2*a4 - a1*a3*a4^2 + a1*a3*a4 and 0
# a2^2*a4^3 + a2*a4^4 - a2^2*a4^2 + (-2.00000000000000)*a2*a4^3 + a2*a4^2 and 0
# ([1, 1], [1, 1, 1, 1])
# n = 1
# i = 1
# a1^2 - a1 and 0
# a2^2 - a2 and 0
# a1*a3 and a1bar*a3bar
# a3^2 - a3 and 0
# a2*a4 and a2bar*a4bar
# a4^2 - a4 and 0

# %% [markdown]
# ## Computation of $r^a_{\lambda, \mu}$
#
# Here we compute Gröbner bases for $r^a_{\lambda, \mu}$ when $a \notin NC_{norm}$, that is for every $i \in \{1, 2, 3, 4\}$, $a_i^2 = a_i$.

# %%
Sa = Ra.quotient([a1^2 - a1, a2^2 - a2, a3^2 - a3, a4^2 - a4])
dic_matrix24_Sa = {}
for couple in dic_matrix24:
    print(couple)
    n = dic_matrix24[couple].nrows()
    m = dic_matrix24[couple].ncols()
    print(n, m)
    dic_matrix24_Sa[couple] = Matrix([[Sa(dic_matrix24[couple][i][j]) for j in range(m)] for i in range(n)])
dic_matrix_simple_24_Sa = Clifton_matrix_simple(dic_matrix24_Sa)
save_matrices_csv(dic_matrix_simple_24_Sa, "Sa/arity24/","")
# Out:
# ([2], [4])
# 96 93
# Interrupting Singular...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _eval_line(self, line, allow_use_file, wait_for_prompt, restart_if_needed)
#     982                     else:
# --> 983                         E.expect(self._prompt)
#     984                 except pexpect.EOF as msg:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/spawnbase.py in expect(self, pattern, timeout, searchwindowsize, async_, **kw)
#     343         return self.expect_list(compiled_pattern_list,
# --> 344                 timeout, searchwindowsize, async_)
#     345
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     500         if (timeout != 0) and select(timeout):
# --> 501             return super(spawn, self).read_nonblocking(size)
#     502
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/spawnbase.py in read_nonblocking(self, size, timeout)
#     168         try:
# --> 169             s = os.read(self.child_fd, size)
#     170         except OSError as err:
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-aceedbed9b2b> in <module>
#       6     m = dic_matrix24[couple].ncols()
#       7     print(n, m)
# ----> 8     dic_matrix24_Sa[couple] = Matrix([[Sa(dic_matrix24[couple][i][j]) for j in range(m)] for i in range(n)])
#       9 dic_matrix_simple_24_Sa = Clifton_matrix_simple(dic_matrix24_Sa)
#      10 save_matrices_csv(dic_matrix_simple_24_Sa, "Sa/arity24/","")
#
# <ipython-input-10-aceedbed9b2b> in <listcomp>(.0)
#       6     m = dic_matrix24[couple].ncols()
#       7     print(n, m)
# ----> 8     dic_matrix24_Sa[couple] = Matrix([[Sa(dic_matrix24[couple][i][j]) for j in range(m)] for i in range(n)])
#       9 dic_matrix_simple_24_Sa = Clifton_matrix_simple(dic_matrix24_Sa)
#      10 save_matrices_csv(dic_matrix_simple_24_Sa, "Sa/arity24/","")
#
# <ipython-input-10-aceedbed9b2b> in <listcomp>(.0)
#       6     m = dic_matrix24[couple].ncols()
#       7     print(n, m)
# ----> 8     dic_matrix24_Sa[couple] = Matrix([[Sa(dic_matrix24[couple][i][j]) for j in range(m)] for i in range(n)])
#       9 dic_matrix_simple_24_Sa = Clifton_matrix_simple(dic_matrix24_Sa)
#      10 save_matrices_csv(dic_matrix_simple_24_Sa, "Sa/arity24/","")
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9336)()
#     896         if mor is not None:
#     897             if no_extra_args:
# --> 898                 return mor._call_(x)
#     899             else:
#     900                 return mor._call_with_args(x, args, kwds)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4514)()
#     154         cdef Parent C = self._codomain
#     155         try:
# --> 156             return C._element_constructor(x)
#     157         except Exception:
#     158             if print_warnings:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/quotient_ring.py in _element_constructor_(self, x, coerce)
#    1013             R = self.cover_ring()
#    1014             x = R(x)
# -> 1015         return self.element_class(self, x)
#    1016
#    1017     def _coerce_map_from_(self, R):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/quotient_ring_element.py in __init__(self, parent, rep, reduce)
#      90         self.__rep = rep
#      91         if reduce:
# ---> 92             self._reduce_()
#      93
#      94     def _reduce_(self):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/quotient_ring_element.py in _reduce_(self)
#     109         """
#     110         I = self.parent().defining_ideal()
# --> 111         self.__rep = I.reduce(self.__rep)
#     112
#     113     def lift(self):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/polynomial/multi_polynomial_ideal.py in reduce(self, f)
#    4528
#    4529         gb = self.groebner_basis()
# -> 4530         return f.reduce(gb)
#    4531
#    4532     def _contains_(self, f):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/polynomial/multi_polynomial_element.py in reduce(self, I)
#    2168         try:
#    2169             fs = self._singular_()
# -> 2170             Is = fs.parent().ideal(I)
#    2171             return P(fs.reduce(Is))
#    2172         except (NotImplementedError, TypeError):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/singular.py in ideal(self, *gens)
#     932         for g in gens:
#     933             if not isinstance(g, SingularElement):
# --> 934                 gens2.append(self.new(g))
#     935             else:
#     936                 gens2.append(g)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/interface.py in new(self, code)
#     367
#     368     def new(self, code):
# --> 369         return self(code)
#     370
#     371     ###################################################################
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/singular.py in __call__(self, x, type)
#     805             return self(x.sage())
#     806         elif not isinstance(x, ExpectElement) and hasattr(x, '_singular_'):
# --> 807             return x._singular_(self)
#     808
#     809         # some convenient conversions
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/polynomial/polynomial_singular_interface.py in _singular_(self, singular, have_ring)
#     420     """
#     421     def _singular_(self, singular=singular, have_ring=False):
# --> 422         return _singular_func(self, singular, have_ring)
#     423
#     424     def _singular_init_func(self, singular=singular, have_ring=False):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/polynomial/polynomial_singular_interface.py in _singular_func(self, singular, have_ring)
#     462     """
#     463     if not have_ring:
# --> 464         self.parent()._singular_(singular).set_ring() #this is expensive
#     465
#     466     try:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/singular.py in set_ring(self)
#    2111             //        block   2 : ordering C
#    2112         """
# -> 2113         self.parent().set_ring(self)
#    2114
#    2115
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/singular.py in set_ring(self, R)
#    1190         if not isinstance(R, SingularElement):
#    1191             raise TypeError("R must be a singular ring")
# -> 1192         self.eval("setring %s; short=0"%R.name(), allow_semicolon=True)
#    1193
#    1194     setring = set_ring
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/singular.py in eval(self, x, allow_semicolon, strip, **kwds)
#     668             x += ';'
#     669
# --> 670         s = Expect.eval(self, x, **kwds)
#     671
#     672         # "Segment fault" is not a typo:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in eval(self, code, strip, synchronize, locals, allow_use_file, split_lines, **kwds)
#    1380                 elif split_lines:
#    1381                     return '\n'.join([self._eval_line(L, allow_use_file=allow_use_file, **kwds)
# -> 1382                                         for L in code.split('\n') if L != ''])
#    1383                 else:
#    1384                     return self._eval_line(code, allow_use_file=allow_use_file, **kwds)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in <listcomp>(.0)
#    1380                 elif split_lines:
#    1381                     return '\n'.join([self._eval_line(L, allow_use_file=allow_use_file, **kwds)
# -> 1382                                         for L in code.split('\n') if L != ''])
#    1383                 else:
#    1384                     return self._eval_line(code, allow_use_file=allow_use_file, **kwds)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _eval_line(self, line, allow_use_file, wait_for_prompt, restart_if_needed)
#    1012                     out = ''
#    1013         except KeyboardInterrupt:
# -> 1014             self._keyboard_interrupt()
#    1015             raise KeyboardInterrupt("Ctrl-c pressed while running %s" % self)
#    1016         if self._terminal_echo:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/singular.py in _keyboard_interrupt(self)
#    1351             raise pexpect.ExceptionPexpect("THIS IS A BUG -- PLEASE REPORT. This should never happen.\n" + msg)
#    1352         self._start()
# -> 1353         raise KeyboardInterrupt("Restarting %s (WARNING: all variables defined in previous session are now invalid)" % self)
#    1354
#    1355
#
# KeyboardInterrupt: Restarting Singular (WARNING: all variables defined in previous session are now invalid)

# %%
list_couples = []
for couple in dic_matrix_simple_24_Sa:
    list_couples.append(couple)
print(list_couples)

# %%
print(list_couples[4], list_couples[9])

# %%
res_Sa = {}
for couple in [list_couples[4], list_couples[9]]:
    print("Couple : " + str(couple))
    M = dic_matrix_simple_24_Sa[couple][1]
    res_Sa[couple] = groebner_bas(M)
    print("Groebner basis : " + str(res_Sa[couple][2]))

# %%
for couple in res_Sa:
    print(couple)
    Gbasis = res_Sa[couple][2]
    n = len(Gbasis)
    print("n = " + str(n))
    for i in range(n):
        print("i = " + str(i))
        for p in Gbasis[i]:
            print(str(p))

# %% [markdown]
# Now we compute Gröbner bases in the polynomial ring $\mathbb{C}[a_2, a_3, a_4, a_5]$. After computing all Groebner bases, we print them in a list. We can see here that the three last terms of the list are $0$, where the sixth one is not, which means that there exists infinitely many $a \in \mathbb{C}^4$ such that $rk(B^a_{\lambda, \mu}) = 6$, thus it doesn't prove our conjecture.

# %%
couple1 = list_couples[9]
print("Couple : " + str(couple1))
M = dic_matrix_simple24[couple1][1]
res = groebner_bas(M)
print(res[2])

# %% [markdown]
# ## Proofs of the three last theorems
#
# Now we can do the same but adding some relations, here we prove the first theorem, because the sixth term is here $0$.

# %%
dic_matrix_simple24_first= {}

for couple in dic_matrix_simple24:
    dic_matrix_simple24_first[couple] = dic_matrix_simple24[couple][1](a1 = 0, a3 = 0)

list_couples = []
for couple in dic_matrix_simple24_first:
    list_couples.append(couple)
    
couple1 = list_couples[-1]
print("Couple : " + str(couple1))
M = dic_matrix_simple24_first[couple1]
res = groebner_bas(M)
print(res[2])

# %% [markdown]
# Here the second theorem

# %%
dic_matrix_simple24_second= {}

for couple in dic_matrix_simple24:
    dic_matrix_simple24_second[couple] = dic_matrix_simple24[couple][1](a2 = 0, a4 = 0)

list_couples = []
for couple in dic_matrix_simple24_second:
    list_couples.append(couple)
    
couple1 = list_couples[-1]
print("Couple : " + str(couple1))
M = dic_matrix_simple24_second[couple1]
res = groebner_bas(M)
print(res[2])

# %% [markdown]
# And the last one.

# %%
dic_matrix_simple24_third= {}

for couple in dic_matrix_simple24:
    dic_matrix_simple24_third[couple] = dic_matrix_simple24[couple][1](a2 = 1, a3 = 0, a4 = 0)

list_couples = []
for couple in dic_matrix_simple24_third:
    list_couples.append(couple)
    
couple1 = list_couples[-1]
print("Couple : " + str(couple1))
M = dic_matrix_simple24_third[couple1]
res = groebner_bas(M)
print(res[2])
